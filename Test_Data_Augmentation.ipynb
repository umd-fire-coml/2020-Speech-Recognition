# %%
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
from data_augmentor import DataAugmentation

# %%
test = DataAugmentation(visualization =  True)

# %%
test.load_data(librosa.util.example_audio_file())

# %%
test.noise_injection()
# Out:
# array([ 0.01473681,  0.0043164 , -0.01996764, ...,  0.01152998,
#        -0.02870392, -0.00464257], dtype=float32)

# %%
test.shifting_time()
# Out:
# array([0.03744841, 0.0363191 , 0.03495054, ..., 0.        , 0.        ,
#        0.        ], dtype=float32)

# %%
test.change_pitch()
# Out:
# array([ 3.7099361e-09,  3.1255452e-09,  1.4908076e-09, ...,
#        -6.7467948e-11,  5.9414546e-10,  0.0000000e+00], dtype=float32)

# %%
test.change_speed()
# Out:
# array([4.3421682e-07, 4.5730641e-07, 3.6970249e-07, ..., 4.4717080e-08,
#        5.7005035e-08, 6.1539730e-08], dtype=float32)
